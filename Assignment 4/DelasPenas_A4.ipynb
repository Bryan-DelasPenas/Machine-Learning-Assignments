# %% [markdown]
# # CMSC478 Machine Learning - Fall 2020
#
# ## Instructor: Fereydoon Vafaei
#
# ## <font color="blue">Assignment-4: Multi-Class Classification and Regression with Neural Networks</font>

# %% [markdown]
# Bryan Delas Penas GW90572

# %% [markdown]
# ## Overview and Learning Objectives

# %% [markdown]
# In Assignment-4, you're going to perform classification and regression using Neural Networks in Tensorflow and Keras.
#
# Pedagogically, this assignment will help you:
# - better understand how neural networks are built and applied on ML tasks - specifically classification and regression.
# - pratice NN implementation using Tensorflow 2 and Keras.

# %% [markdown]
# **Notice**: While some outputs are provided as reference, other outputs are NOT shared intentionally, and you should not share them or any solution code in Piazza.
#
# **Very Important Note:** You must run all cells and generate all outputs and plots. Notebooks with incomplete outputs will NOT be graded and will get ZERO credit!

# %% [markdown]
# ## Part I - Multi-Class Classification Using NN

# %% [markdown]
# First download the [data](https://github.com/fereydoonvafaei/CMSC478-Fall2020/blob/master/data/video-games.csv). This is the same video games dataset you used in Assignment-2. You can read the descriptions of the data [here](https://www.kaggle.com/rush4ratio/video-game-sales-with-ratings). You are going to do multi-class classification on **Rating**.

# %% [markdown]
# ## <font color="red"> Required Coding

# %%
# Import necessary Python modules as well as Tensorflow and Keras
import tensorflow as tf

from tensorflow import keras
from tensorflow.keras import layers
from sklearn.model_selection import train_test_split

import pandas as pd
import numpy as np
from sklearn.metrics import classification_report 
import matplotlib.pyplot as plt
# %matplotlib inline

import warnings
warnings.filterwarnings("ignore")
import warnings
warnings.filterwarnings("ignore")

# %%
print("tf Version: ", tf.__version__)
print("Eager Execution mode: ", tf.executing_eagerly())
# Out:
# tf Version:  2.1.0
# Eager Execution mode:  True

# %% [markdown]
# > Load the data and do all the required preprocessing steps that you did in Assignment-2 for classification on "Rating".

# %%
# Load the data as a dataframe using pandas
game_data = pd.read_csv("video-games.csv")
print(game_data.shape)
game_data.head()
# Out:
# (16719, 16)
#                        Name Platform  Year_of_Release         Genre Publisher  \
# 0                Wii Sports      Wii           2006.0        Sports  Nintendo
# 1         Super Mario Bros.      NES           1985.0      Platform  Nintendo
# 2            Mario Kart Wii      Wii           2008.0        Racing  Nintendo
# 3         Wii Sports Resort      Wii           2009.0        Sports  Nintendo
# 4  Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  Critic_Score  \
# 0     41.36     28.96      3.77         8.45         82.53          76.0
# 1     29.08      3.58      6.81         0.77         40.24           NaN
# 2     15.68     12.76      3.79         3.29         35.52          82.0
# 3     15.61     10.93      3.28         2.95         32.77          80.0
# 4     11.27      8.89     10.22         1.00         31.37           NaN
#
#    Critic_Count User_Score  User_Count Developer Rating
# 0          51.0          8       322.0  Nintendo      E
# 1           NaN        NaN         NaN       NaN    NaN
# 2          73.0        8.3       709.0  Nintendo      E
# 3          73.0          8       192.0  Nintendo      E
# 4           NaN        NaN         NaN       NaN    NaN

# %% [markdown]
# > Notice that preprocessing in A4, while extremely important to get the correct results moving forward, has no credit on its own because it's the same as A2.

# %% [markdown]
# ### Preprocessing

# %%
# Drop NAs
game_data = game_data.dropna()
print(game_data.shape)
game_data.head()
# Out:
# (6825, 16)
#                     Name Platform  Year_of_Release     Genre Publisher  \
# 0             Wii Sports      Wii           2006.0    Sports  Nintendo
# 2         Mario Kart Wii      Wii           2008.0    Racing  Nintendo
# 3      Wii Sports Resort      Wii           2009.0    Sports  Nintendo
# 6  New Super Mario Bros.       DS           2006.0  Platform  Nintendo
# 7               Wii Play      Wii           2006.0      Misc  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  Critic_Score  \
# 0     41.36     28.96      3.77         8.45         82.53          76.0
# 2     15.68     12.76      3.79         3.29         35.52          82.0
# 3     15.61     10.93      3.28         2.95         32.77          80.0
# 6     11.28      9.14      6.50         2.88         29.80          89.0
# 7     13.96      9.18      2.93         2.84         28.92          58.0
#
#    Critic_Count User_Score  User_Count Developer Rating
# 0          51.0          8       322.0  Nintendo      E
# 2          73.0        8.3       709.0  Nintendo      E
# 3          73.0          8       192.0  Nintendo      E
# 6          65.0        8.5       431.0  Nintendo      E
# 7          41.0        6.6       129.0  Nintendo      E

# %%
# Drop "Name" column as it does not provide any useful info
game_data = game_data.drop('Name',1)
print(game_data.shape)
game_data.head()
# Out:
# (6825, 15)
#   Platform  Year_of_Release     Genre Publisher  NA_Sales  EU_Sales  JP_Sales  \
# 0      Wii           2006.0    Sports  Nintendo     41.36     28.96      3.77
# 2      Wii           2008.0    Racing  Nintendo     15.68     12.76      3.79
# 3      Wii           2009.0    Sports  Nintendo     15.61     10.93      3.28
# 6       DS           2006.0  Platform  Nintendo     11.28      9.14      6.50
# 7      Wii           2006.0      Misc  Nintendo     13.96      9.18      2.93
#
#    Other_Sales  Global_Sales  Critic_Score  Critic_Count User_Score  \
# 0         8.45         82.53          76.0          51.0          8
# 2         3.29         35.52          82.0          73.0        8.3
# 3         2.95         32.77          80.0          73.0          8
# 6         2.88         29.80          89.0          65.0        8.5
# 7         2.84         28.92          58.0          41.0        6.6
#
#    User_Count Developer Rating
# 0       322.0  Nintendo      E
# 2       709.0  Nintendo      E
# 3       192.0  Nintendo      E
# 6       431.0  Nintendo      E
# 7       129.0  Nintendo      E

# %%
# Drop "Global_Sales" column as it is redundant feature - it's just sum of regional and other sales
game_data = game_data.drop('Global_Sales',1)
print(game_data.shape)
game_data.head()
# Out:
# (6825, 14)
#   Platform  Year_of_Release     Genre Publisher  NA_Sales  EU_Sales  JP_Sales  \
# 0      Wii           2006.0    Sports  Nintendo     41.36     28.96      3.77
# 2      Wii           2008.0    Racing  Nintendo     15.68     12.76      3.79
# 3      Wii           2009.0    Sports  Nintendo     15.61     10.93      3.28
# 6       DS           2006.0  Platform  Nintendo     11.28      9.14      6.50
# 7      Wii           2006.0      Misc  Nintendo     13.96      9.18      2.93
#
#    Other_Sales  Critic_Score  Critic_Count User_Score  User_Count Developer  \
# 0         8.45          76.0          51.0          8       322.0  Nintendo
# 2         3.29          82.0          73.0        8.3       709.0  Nintendo
# 3         2.95          80.0          73.0          8       192.0  Nintendo
# 6         2.88          89.0          65.0        8.5       431.0  Nintendo
# 7         2.84          58.0          41.0        6.6       129.0  Nintendo
#
#   Rating
# 0      E
# 2      E
# 3      E
# 6      E
# 7      E

# %%
# Get feature vector X (all columns but "Rating") and target label y as "Rating"
X = game_data.loc[:,game_data.columns != 'Rating']
y = game_data['Rating']

# %%
# Print X shape and head
print(X.shape)
X.head()
# Out:
# (6825, 13)
#   Platform  Year_of_Release     Genre Publisher  NA_Sales  EU_Sales  JP_Sales  \
# 0      Wii           2006.0    Sports  Nintendo     41.36     28.96      3.77
# 2      Wii           2008.0    Racing  Nintendo     15.68     12.76      3.79
# 3      Wii           2009.0    Sports  Nintendo     15.61     10.93      3.28
# 6       DS           2006.0  Platform  Nintendo     11.28      9.14      6.50
# 7      Wii           2006.0      Misc  Nintendo     13.96      9.18      2.93
#
#    Other_Sales  Critic_Score  Critic_Count User_Score  User_Count Developer
# 0         8.45          76.0          51.0          8       322.0  Nintendo
# 2         3.29          82.0          73.0        8.3       709.0  Nintendo
# 3         2.95          80.0          73.0          8       192.0  Nintendo
# 6         2.88          89.0          65.0        8.5       431.0  Nintendo
# 7         2.84          58.0          41.0        6.6       129.0  Nintendo

# %%
# Using pandas.get_dummies() create dummy variables for categorical features
X = pd.get_dummies(X)
print(X.shape)
X.head()
# Out:
# (6825, 1677)
#    Year_of_Release  NA_Sales  EU_Sales  JP_Sales  Other_Sales  Critic_Score  \
# 0           2006.0     41.36     28.96      3.77         8.45          76.0
# 2           2008.0     15.68     12.76      3.79         3.29          82.0
# 3           2009.0     15.61     10.93      3.28         2.95          80.0
# 6           2006.0     11.28      9.14      6.50         2.88          89.0
# 7           2006.0     13.96      9.18      2.93         2.84          58.0
#
#    Critic_Count  User_Count  Platform_3DS  Platform_DC  ...  \
# 0          51.0       322.0             0            0  ...
# 2          73.0       709.0             0            0  ...
# 3          73.0       192.0             0            0  ...
# 6          65.0       431.0             0            0  ...
# 7          41.0       129.0             0            0  ...
#
#    Developer_h.a.n.d. Inc.  Developer_iNiS  Developer_id Software  \
# 0                        0               0                      0
# 2                        0               0                      0
# 3                        0               0                      0
# 6                        0               0                      0
# 7                        0               0                      0
#
#    Developer_id Software, Nerve Software  \
# 0                                      0
# 2                                      0
# 3                                      0
# 6                                      0
# 7                                      0
#
#    Developer_id Software, Raven Software  Developer_n-Space  \
# 0                                      0                  0
# 2                                      0                  0
# 3                                      0                  0
# 6                                      0                  0
# 7                                      0                  0
#
#    Developer_neo Software  Developer_odenis studio  Developer_syn Sophia  \
# 0                       0                        0                     0
# 2                       0                        0                     0
# 3                       0                        0                     0
# 6                       0                        0                     0
# 7                       0                        0                     0
#
#    Developer_zSlide
# 0                 0
# 2                 0
# 3                 0
# 6                 0
# 7                 0
#
# [5 rows x 1677 columns]

# %%
# Print y shape and head and its unique values
print(y.shape)
print(y.unique())
y.head()
# Out:
# (6825,)
# ['E' 'M' 'T' 'E10+' 'AO' 'K-A' 'RP']
# 0    E
# 2    E
# 3    E
# 6    E
# 7    E
# Name: Rating, dtype: object

# %% [markdown]
# > <b>Note:</b> The output of the following cells is provided to you for your reference. All the following cells depend on the correctness of your preprocessing steps and can be verified by these outputs.

# %%
# Convert categorical class labels to numerical
y = y = y.map(lambda x: {'E' :0, 'E10+' :1, 'T' :2, 'M' :3, 'AO' :4, 'K-A' :5, 'RP' :6}.get(x))

print(y.unique())
print(y.shape)
print(type(y))
y.head()
# Out:
# [0 3 2 1 4 5 6]
# (6825,)
# <class 'pandas.core.series.Series'>
# 0    0
# 2    0
# 3    0
# 6    0
# 7    0
# Name: Rating, dtype: int64

# %%
# Normalize X using mean() and std()  NOTE: The output is provided for your reference.
mean = np.mean(X)
std = np.std(X)
X-= mean
X /= std

print(X.shape)
X.head()
# Out:
# (6825, 1677)
#    Year_of_Release   NA_Sales   EU_Sales   JP_Sales  Other_Sales  \
# 0        -0.341201  42.349741  41.793631  12.887711    31.007176
# 2         0.133752  15.802014  18.222438  12.957265    11.885525
# 3         0.371229  15.729649  15.559767  11.183651    10.625572
# 6        -0.341201  11.253338  12.955296  22.381762    10.366169
# 7        -0.341201  14.023895  13.013496   9.966465    10.217939
#
#    Critic_Score  Critic_Count  User_Count  Platform_3DS  Platform_DC  ...  \
# 0      0.413044      1.148059    0.250734     -0.152441    -0.045338  ...
# 2      0.845709      2.292536    0.909586     -0.152441    -0.045338  ...
# 3      0.701487      2.292536    0.029415     -0.152441    -0.045338  ...
# 6      1.350484      1.876363    0.436302     -0.152441    -0.045338  ...
# 7     -0.884950      0.627843   -0.077840     -0.152441    -0.045338  ...
#
#    Developer_h.a.n.d. Inc.  Developer_iNiS  Developer_id Software  \
# 0                -0.029663       -0.024216              -0.034257
# 2                -0.029663       -0.024216              -0.034257
# 3                -0.029663       -0.024216              -0.034257
# 6                -0.029663       -0.024216              -0.034257
# 7                -0.029663       -0.024216              -0.034257
#
#    Developer_id Software, Nerve Software  \
# 0                              -0.012105
# 2                              -0.012105
# 3                              -0.012105
# 6                              -0.012105
# 7                              -0.012105
#
#    Developer_id Software, Raven Software  Developer_n-Space  \
# 0                               -0.02097          -0.043685
# 2                               -0.02097          -0.043685
# 3                               -0.02097          -0.043685
# 6                               -0.02097          -0.043685
# 7                               -0.02097          -0.043685
#
#    Developer_neo Software  Developer_odenis studio  Developer_syn Sophia  \
# 0               -0.012105                -0.012105             -0.017121
# 2               -0.012105                -0.012105             -0.017121
# 3               -0.012105                -0.012105             -0.017121
# 6               -0.012105                -0.012105             -0.017121
# 7               -0.012105                -0.012105             -0.017121
#
#    Developer_zSlide
# 0         -0.012105
# 2         -0.012105
# 3         -0.012105
# 6         -0.012105
# 7         -0.012105
#
# [5 rows x 1677 columns]

# %%
# Split the data to train and test with ratio of 80/20 for train/test respectively
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size = 0.2)

print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (5460, 1677)
# (5460,)
# (1365, 1677)
# (1365,)

# %% [markdown]
# > Now, you should put the data into tensors. Be aware though that there are other ways to prepare the data in tensorflow.

# %%
# Batch train and test data
train_tensor = tf.data.Dataset.from_tensor_slices((X_train.values, y_train.values))
test_tensor = tf.data.Dataset.from_tensor_slices((X_test.values, y_test.values))
train_batch = train_tensor.shuffle(len(X_train)).batch(10)
test_batch = test_tensor.shuffle(len(X_test)).batch(10)
# Out:
# <BatchDataset shapes: ((None, 1677), (None,)), types: (tf.float64, tf.int64)>

# %%
type(train_tensor)
# Out:
# tensorflow.python.data.ops.dataset_ops.TensorSliceDataset

# %%
train_tensor.element_spec
# Out:
# (TensorSpec(shape=(1677,), dtype=tf.float64, name=None),
#  TensorSpec(shape=(), dtype=tf.int64, name=None))

# %% [markdown]
# ### Building the NN for Multi-Class Classification

# %% [markdown]
# > You can begin with a simple neural network with a couple of hidden layers, and increase number of hidden layers and neurons as needed. You may also use callback and early stopping to find the optimal number of epochs, but it's possible to obtain the minimum required accuracy (0.70) with 20 epochs only.
#
# > **Hint**: During training, you should see a clear trend of descending loss and increasing accuracy epoch after epoch; otherwise, your model has not been developed properly.
#
# > **Very Important Note**: All your cells should be run and show outputs and/or plots!

# %%
# Build a sequential NN with appropriate layers for multi-class classification
# Use ReLU for all hidden layers

# Hint1: input_dim of the first layer should match with the number of features in X_train

# Hint2: Notice that the activation function and number of neurons in the output layer are determined
# by the type of ML task i.e. Multi-class Classification
nn_clf = tf.keras.Sequential([
    # Add layers accordingly
    layers.Dense(7,input_dim=X_train.shape[1], activation="relu", name="layer1"),
    layers.Dense(14,activation="softmax", name="layer2"),
    layers.Dense(21,activation="softmax", name="layer3"),
])

# %%
nn_clf.summary()
# Out:
# Model: "sequential_34"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# layer1 (Dense)               (None, 7)                 11746
# _________________________________________________________________
# layer2 (Dense)               (None, 14)                112
# _________________________________________________________________
# layer3 (Dense)               (None, 21)                315
# =================================================================
# Total params: 12,173
# Trainable params: 12,173
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# > You're going to use [SparseCategoricalCrossentropy](https://www.tensorflow.org/api_docs/python/tf/keras/losses/SparseCategoricalCrossentropy) for loss function because as the Tensorflow documentation says:
#
# > "Use this crossentropy loss function when there are two or more label classes. We expect labels to be provided as integers. If you want to provide labels using one-hot representation, please use [`CategoricalCrossentropy` ](https://www.tensorflow.org/api_docs/python/tf/keras/losses/CategoricalCrossentropy) loss."

# %%
# Compile nn_clf with loss='sparse_categorical_crossentropy' and metrics=['sparse_categorical_accuracy']
# Hint1: One of the hyperparameters you can change is the optimizer (Adam, RMSprop, SGD, ...)
# Hint2: The other impactful hyperparameter is learning_rate
opt = keras.optimizers.Adam(learning_rate=0.01)
nn_clf.compile(loss='sparse_categorical_crossentropy',optimizer=opt, metrics=['sparse_categorical_accuracy'])

# %% [markdown]
# > To train the model, you use `fit()` method, and since you've created `train_batch`, you don't need to pass `y_train` as it's already included in the batch.

# %%
# Fit the network on train_batch with 20 epochs (you may train with more epochs or use callback if needed)
nn_clf_history = nn_clf.fit(train_batch,epochs=20)
# Out:
# Train for 546 steps
# Epoch 1/20
# 546/546 [==============================] - 1s 937us/step - loss: 0.5741 - sparse_categorical_accuracy: 0.8240
# Epoch 2/20
# 546/546 [==============================] - 0s 884us/step - loss: 0.5724 - sparse_categorical_accuracy: 0.8240
# Epoch 3/20
# 546/546 [==============================] - 0s 874us/step - loss: 0.5712 - sparse_categorical_accuracy: 0.8245
# Epoch 4/20
# 546/546 [==============================] - 0s 864us/step - loss: 0.5765 - sparse_categorical_accuracy: 0.8227
# Epoch 5/20
# 546/546 [==============================] - 1s 938us/step - loss: 0.5802 - sparse_categorical_accuracy: 0.8190
# Epoch 6/20
# 546/546 [==============================] - 0s 867us/step - loss: 0.5736 - sparse_categorical_accuracy: 0.8253
# Epoch 7/20
# 546/546 [==============================] - 0s 859us/step - loss: 0.5559 - sparse_categorical_accuracy: 0.8293
# Epoch 8/20
# 546/546 [==============================] - 0s 848us/step - loss: 0.5562 - sparse_categorical_accuracy: 0.8313
# Epoch 9/20
# 546/546 [==============================] - 0s 854us/step - loss: 0.5525 - sparse_categorical_accuracy: 0.8306
# Epoch 10/20
# 546/546 [==============================] - 0s 864us/step - loss: 0.5468 - sparse_categorical_accuracy: 0.8370
# Epoch 11/20
# 546/546 [==============================] - 0s 879us/step - loss: 0.5505 - sparse_categorical_accuracy: 0.8333
# Epoch 12/20
# 546/546 [==============================] - 0s 906us/step - loss: 0.5605 - sparse_categorical_accuracy: 0.8324
# Epoch 13/20
# 546/546 [==============================] - 0s 868us/step - loss: 0.5557 - sparse_categorical_accuracy: 0.8321
# Epoch 14/20
# 546/546 [==============================] - 0s 864us/step - loss: 0.5543 - sparse_categorical_accuracy: 0.8359
# Epoch 15/20
# 546/546 [==============================] - 0s 868us/step - loss: 0.5573 - sparse_categorical_accuracy: 0.8379
# Epoch 16/20
# 546/546 [==============================] - 0s 883us/step - loss: 0.5538 - sparse_categorical_accuracy: 0.8350
# Epoch 17/20
# 546/546 [==============================] - 0s 888us/step - loss: 0.5500 - sparse_categorical_accuracy: 0.8339
# Epoch 18/20
# 546/546 [==============================] - 0s 889us/step - loss: 0.5403 - sparse_categorical_accuracy: 0.8381
# Epoch 19/20
# 546/546 [==============================] - 0s 872us/step - loss: 0.5503 - sparse_categorical_accuracy: 0.8368
# Epoch 20/20
# 546/546 [==============================] - 0s 895us/step - loss: 0.5457 - sparse_categorical_accuracy: 0.8355

# %%
pd.DataFrame(nn_clf_history.history).plot(figsize=(10, 5))
plt.grid(True)

# Set the xticks - label locations
plt.xticks(np.arange(0, 20, step=2))  

# set the y-axis range to [0-1]
plt.gca().set_ylim(0, 1)
# Out:
# (0, 1)

# %% [markdown]
# > To evaluate the model, you use `evaluate()` method.
#
# > <font color='red'>**Minimum Accuracy Requirement**</font>: Your accuracy on `test_batch` must be at least **0.70**. Otherwise, your notebook will get NO CREDIT for this part, so you must fine-tune your `nn_clf` accordingly.

# %%
# Evaluate the model on test_batch - no need to pass y_test because it's included in test_batch
cross_entropy_loss, accuracy = nn_clf.evaluate(test_batch)
# Out:
# 137/137 [==============================] - 0s 598us/step - loss: 0.9128 - sparse_categorical_accuracy: 0.7048

# %%
# Minimum Required Accuracy: 0.70
round(accuracy, 2)
# Out:
# 0.7

# %%
y_pred = nn_clf.predict_classes(X_test)

# %%
y_pred
# Out:
# array([3, 2, 0, ..., 0, 3, 0], dtype=int64)

# %% [markdown]
# > Get a [classification report](https://scikit-learn.org/stable/modules/generated/sklearn.metrics.classification_report.html).

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.72      0.86      0.78       432
#            1       0.62      0.32      0.42       179
#            2       0.69      0.71      0.70       486
#            3       0.73      0.71      0.72       267
#            6       0.00      0.00      0.00         1
#
#     accuracy                           0.70      1365
#    macro avg       0.55      0.52      0.53      1365
# weighted avg       0.70      0.70      0.69      1365

# %% [markdown]
# > Next, you're going to fine-tune your learning-rate specifically. To do so and to avoid repeating the code, let's write a function.

# %%
def build_model():
    nn_clf = tf.keras.Sequential([
        # Add layers accordingly
        layers.Dense(7,input_dim=X_train.shape[1], activation="relu", name="layer1"),
        layers.Dense(14,activation="softmax", name="layer2"),
        layers.Dense(21,activation="softmax", name="layer3"),
        ])  
    return nn_clf

# %% [markdown]
# > The learning rate range that you're going to investigate is between 0.001 and 0.1 with an increment step of 0.001. Use the optimizer of your choice that performed the best in your fine-tuning, and don't change it in the `for` loop.
#
# > It's possible to try different learning rate scheduling policies, including those policies with an exponential decay rate, but you narrow down your investigation on this specific range for this part of the assignment.
#
# > Running this cell may take a few minutes!

# %%
accuracies = []
learning_rates = np.arange(0.001, 0.011, 0.001)

for i in learning_rates:
    nn_clf = build_model()
    opt = keras.optimizers.Adam(learning_rate=i)
    nn_clf.compile(loss='sparse_categorical_crossentropy',optimizer=opt, metrics=['sparse_categorical_accuracy'])
    nn_clf_history = nn_clf.fit(train_batch,epochs=20)
    cross_entropy_loss, accuracy = nn_clf.evaluate(test_batch)
    accuracies.append(round(accuracy, 2))  
    
''' Write a for loop that iterates over learning_rate
    In each iteration:
        build a new model by calling build_model(),
        compile with the optimizer of your choice and the current learning_rate,
        train on train_batch with 20 epochs,
        evaluate on test_batch and get the accuracy,
        append accuracy to accuracies
'''
for lr in learning_rates: #lr is current learning rate
    print("lr = ",lr)

for a in accuracies:
    print("accuracy = ", a)
# Out:
# Train for 546 steps
# Epoch 1/20
# 546/546 [==============================] - 1s 1ms/step - loss: 2.2608 - sparse_categorical_accuracy: 0.3824
# Epoch 2/20
# 546/546 [==============================] - 1s 959us/step - loss: 1.5248 - sparse_categorical_accuracy: 0.4751
# Epoch 3/20
# 546/546 [==============================] - 0s 873us/step - loss: 1.2703 - sparse_categorical_accuracy: 0.5278
# Epoch 4/20
# 546/546 [==============================] - 0s 849us/step - loss: 1.1362 - sparse_categorical_accuracy: 0.5401
# Epoch 5/20
# 546/546 [==============================] - 1s 921us/step - loss: 1.0527 - sparse_categorical_accuracy: 0.5531
# Epoch 6/20
# 546/546 [==============================] - 0s 863us/step - loss: 1.0006 - sparse_categorical_accuracy: 0.5403
# Epoch 7/20
# 546/546 [==============================] - 0s 887us/step - loss: 0.9638 - sparse_categorical_accuracy: 0.5495
# Epoch 8/20
# 546/546 [==============================] - 0s 898us/step - loss: 0.9399 - sparse_categorical_accuracy: 0.5509
# Epoch 9/20
# 546/546 [==============================] - 0s 856us/step - loss: 0.9222 - sparse_categorical_accuracy: 0.5557
# Epoch 10/20
# 546/546 [==============================] - 0s 849us/step - loss: 0.9063 - sparse_categorical_accuracy: 0.5582
# Epoch 11/20
# 546/546 [==============================] - 0s 905us/step - loss: 0.8908 - sparse_categorical_accuracy: 0.5632
# Epoch 12/20
# 546/546 [==============================] - 0s 880us/step - loss: 0.8789 - sparse_categorical_accuracy: 0.5872
# Epoch 13/20
# 546/546 [==============================] - 1s 942us/step - loss: 0.8652 - sparse_categorical_accuracy: 0.6505
# Epoch 14/20
# 546/546 [==============================] - 0s 897us/step - loss: 0.8518 - sparse_categorical_accuracy: 0.6518
# Epoch 15/20
# 546/546 [==============================] - 1s 954us/step - loss: 0.8399 - sparse_categorical_accuracy: 0.6608
# Epoch 16/20
# 546/546 [==============================] - 0s 879us/step - loss: 0.8276 - sparse_categorical_accuracy: 0.6696
# Epoch 17/20
# 546/546 [==============================] - 0s 893us/step - loss: 0.8138 - sparse_categorical_accuracy: 0.6753
# Epoch 18/20
# 546/546 [==============================] - 1s 969us/step - loss: 0.8008 - sparse_categorical_accuracy: 0.6877
# Epoch 19/20
# 546/546 [==============================] - 0s 906us/step - loss: 0.7867 - sparse_categorical_accuracy: 0.6980
# Epoch 20/20
# 546/546 [==============================] - 0s 902us/step - loss: 0.7751 - sparse_categorical_accuracy: 0.7026
# 137/137 [==============================] - 0s 1ms/step - loss: 0.9524 - sparse_categorical_accuracy: 0.5985
# Train for 546 steps
# Epoch 1/20
# 546/546 [==============================] - 1s 1ms/step - loss: 1.9254 - sparse_categorical_accuracy: 0.4408
# Epoch 2/20
# 546/546 [==============================] - 0s 892us/step - loss: 1.2133 - sparse_categorical_accuracy: 0.5134
# Epoch 3/20
# 546/546 [==============================] - 0s 863us/step - loss: 1.0602 - sparse_categorical_accuracy: 0.5419
# Epoch 4/20
# 546/546 [==============================] - 0s 899us/step - loss: 0.9891 - sparse_categorical_accuracy: 0.5621
# Epoch 5/20
# 546/546 [==============================] - 0s 886us/step - loss: 0.9515 - sparse_categorical_accuracy: 0.5736
# Epoch 6/20
# 546/546 [==============================] - 0s 877us/step - loss: 0.9362 - sparse_categorical_accuracy: 0.5744
# Epoch 7/20
# 546/546 [==============================] - 1s 964us/step - loss: 0.9212 - sparse_categorical_accuracy: 0.5773
# Epoch 8/20
# 546/546 [==============================] - 0s 886us/step - loss: 0.9064 - sparse_categorical_accuracy: 0.5817
# Epoch 9/20
# 546/546 [==============================] - 0s 847us/step - loss: 0.8978 - sparse_categorical_accuracy: 0.5852
# Epoch 10/20
# 546/546 [==============================] - 0s 892us/step - loss: 0.8869 - sparse_categorical_accuracy: 0.5863
# Epoch 11/20
# 546/546 [==============================] - 0s 913us/step - loss: 0.8739 - sparse_categorical_accuracy: 0.5870
# Epoch 12/20
# 546/546 [==============================] - 0s 865us/step - loss: 0.8626 - sparse_categorical_accuracy: 0.5899
# Epoch 13/20
# 546/546 [==============================] - 0s 877us/step - loss: 0.8518 - sparse_categorical_accuracy: 0.6150
# Epoch 14/20
# 546/546 [==============================] - 0s 876us/step - loss: 0.8304 - sparse_categorical_accuracy: 0.6557
# Epoch 15/20
# 546/546 [==============================] - 0s 836us/step - loss: 0.8088 - sparse_categorical_accuracy: 0.6780
# Epoch 16/20
# 546/546 [==============================] - 0s 868us/step - loss: 0.7779 - sparse_categorical_accuracy: 0.6980
# Epoch 17/20
# 546/546 [==============================] - 0s 864us/step - loss: 0.7490 - sparse_categorical_accuracy: 0.7137
# Epoch 18/20
# 546/546 [==============================] - 0s 905us/step - loss: 0.7161 - sparse_categorical_accuracy: 0.7267
# Epoch 19/20
# 546/546 [==============================] - 0s 855us/step - loss: 0.6653 - sparse_categorical_accuracy: 0.7473
# Epoch 20/20
# 546/546 [==============================] - 0s 889us/step - loss: 0.6188 - sparse_categorical_accuracy: 0.7672
# 137/137 [==============================] - 0s 1ms/step - loss: 0.9485 - sparse_categorical_accuracy: 0.6432
# Train for 546 steps
# Epoch 1/20
# 546/546 [==============================] - 1s 1ms/step - loss: 1.8166 - sparse_categorical_accuracy: 0.3156
# Epoch 2/20
# 546/546 [==============================] - 0s 901us/step - loss: 1.3933 - sparse_categorical_accuracy: 0.3454
# Epoch 3/20
# 546/546 [==============================] - 0s 905us/step - loss: 1.3342 - sparse_categorical_accuracy: 0.3648
# Epoch 4/20
# 546/546 [==============================] - 1s 920us/step - loss: 1.2083 - sparse_categorical_accuracy: 0.4350
# Epoch 5/20
# 546/546 [==============================] - 0s 913us/step - loss: 1.1086 - sparse_categorical_accuracy: 0.5092
# Epoch 6/20
# 546/546 [==============================] - 1s 916us/step - loss: 0.9572 - sparse_categorical_accuracy: 0.6159
# Epoch 7/20
# 546/546 [==============================] - 0s 893us/step - loss: 0.8563 - sparse_categorical_accuracy: 0.6630
# Epoch 8/20
# 546/546 [==============================] - 0s 890us/step - loss: 0.8096 - sparse_categorical_accuracy: 0.6810
# Epoch 9/20
# 546/546 [==============================] - 0s 832us/step - loss: 0.7733 - sparse_categorical_accuracy: 0.6912
# Epoch 10/20
# 546/546 [==============================] - 0s 838us/step - loss: 0.7445 - sparse_categorical_accuracy: 0.7042
# Epoch 11/20
# 546/546 [==============================] - 0s 837us/step - loss: 0.7193 - sparse_categorical_accuracy: 0.7137
# Epoch 12/20
# 546/546 [==============================] - 0s 865us/step - loss: 0.6953 - sparse_categorical_accuracy: 0.7227
# Epoch 13/20
# 546/546 [==============================] - 0s 843us/step - loss: 0.6726 - sparse_categorical_accuracy: 0.7319
# Epoch 14/20
# 546/546 [==============================] - 0s 836us/step - loss: 0.6547 - sparse_categorical_accuracy: 0.7414
# Epoch 15/20
# 546/546 [==============================] - 0s 826us/step - loss: 0.6313 - sparse_categorical_accuracy: 0.7540
# Epoch 16/20
# 546/546 [==============================] - 0s 856us/step - loss: 0.6108 - sparse_categorical_accuracy: 0.7683
# Epoch 17/20
# 546/546 [==============================] - 0s 871us/step - loss: 0.6032 - sparse_categorical_accuracy: 0.7769
# Epoch 18/20
# 546/546 [==============================] - 0s 839us/step - loss: 0.5856 - sparse_categorical_accuracy: 0.7815
# Epoch 19/20
# 546/546 [==============================] - 0s 876us/step - loss: 0.5676 - sparse_categorical_accuracy: 0.7962
# Epoch 20/20
# 546/546 [==============================] - 0s 836us/step - loss: 0.5541 - sparse_categorical_accuracy: 0.8048
# 137/137 [==============================] - 0s 1ms/step - loss: 0.9367 - sparse_categorical_accuracy: 0.6784
# Train for 546 steps
# Epoch 1/20
# 546/546 [==============================] - 1s 2ms/step - loss: 1.7068 - sparse_categorical_accuracy: 0.3361
# Epoch 2/20
# 546/546 [==============================] - 0s 866us/step - loss: 1.3358 - sparse_categorical_accuracy: 0.3744
# Epoch 3/20
# 546/546 [==============================] - 0s 857us/step - loss: 1.1620 - sparse_categorical_accuracy: 0.4861
# Epoch 4/20
# 546/546 [==============================] - 0s 848us/step - loss: 1.0602 - sparse_categorical_accuracy: 0.5397
# Epoch 5/20
# 546/546 [==============================] - 0s 895us/step - loss: 0.9297 - sparse_categorical_accuracy: 0.6275
# Epoch 6/20
# 546/546 [==============================] - 0s 836us/step - loss: 0.8363 - sparse_categorical_accuracy: 0.6736
# Epoch 7/20
# 546/546 [==============================] - 0s 892us/step - loss: 0.7792 - sparse_categorical_accuracy: 0.6995
# Epoch 8/20
# 546/546 [==============================] - 1s 955us/step - loss: 0.7211 - sparse_categorical_accuracy: 0.7335
# Epoch 9/20
# 546/546 [==============================] - 0s 821us/step - loss: 0.6649 - sparse_categorical_accuracy: 0.7597
# Epoch 10/20
# 546/546 [==============================] - 0s 844us/step - loss: 0.6105 - sparse_categorical_accuracy: 0.7842
# Epoch 11/20
# 546/546 [==============================] - 0s 911us/step - loss: 0.5705 - sparse_categorical_accuracy: 0.8015
# Epoch 12/20
# 546/546 [==============================] - 0s 895us/step - loss: 0.5315 - sparse_categorical_accuracy: 0.8231
# Epoch 13/20
# 546/546 [==============================] - 0s 879us/step - loss: 0.5118 - sparse_categorical_accuracy: 0.8322
# Epoch 14/20
# 546/546 [==============================] - 0s 894us/step - loss: 0.4925 - sparse_categorical_accuracy: 0.8363
# Epoch 15/20
# 546/546 [==============================] - 0s 873us/step - loss: 0.4631 - sparse_categorical_accuracy: 0.8505
# Epoch 16/20
# 546/546 [==============================] - 0s 873us/step - loss: 0.4454 - sparse_categorical_accuracy: 0.8568
# Epoch 17/20
# 546/546 [==============================] - 0s 880us/step - loss: 0.4257 - sparse_categorical_accuracy: 0.8630
# Epoch 18/20
# 546/546 [==============================] - 0s 844us/step - loss: 0.4196 - sparse_categorical_accuracy: 0.8663
# Epoch 19/20
# 546/546 [==============================] - 0s 909us/step - loss: 0.4074 - sparse_categorical_accuracy: 0.8703
# Epoch 20/20
# 546/546 [==============================] - 0s 878us/step - loss: 0.3936 - sparse_categorical_accuracy: 0.8747
# 137/137 [==============================] - 0s 1ms/step - loss: 1.0664 - sparse_categorical_accuracy: 0.6799
# Train for 546 steps
# Epoch 1/20
# 546/546 [==============================] - 1s 1ms/step - loss: 1.5515 - sparse_categorical_accuracy: 0.4179
# Epoch 2/20
# 546/546 [==============================] - 0s 889us/step - loss: 1.1066 - sparse_categorical_accuracy: 0.4916
# Epoch 3/20
# 546/546 [==============================] - 0s 893us/step - loss: 1.0475 - sparse_categorical_accuracy: 0.5148
# Epoch 4/20
# 546/546 [==============================] - 1s 919us/step - loss: 1.0049 - sparse_categorical_accuracy: 0.5350
# Epoch 5/20
# 546/546 [==============================] - 0s 909us/step - loss: 0.9594 - sparse_categorical_accuracy: 0.5778
# Epoch 6/20
# 546/546 [==============================] - 0s 868us/step - loss: 0.8671 - sparse_categorical_accuracy: 0.6511
# Epoch 7/20
# 546/546 [==============================] - 1s 948us/step - loss: 0.7958 - sparse_categorical_accuracy: 0.6890
# Epoch 8/20
# 546/546 [==============================] - 0s 873us/step - loss: 0.7447 - sparse_categorical_accuracy: 0.7174
# Epoch 9/20
# 546/546 [==============================] - 1s 917us/step - loss: 0.7093 - sparse_categorical_accuracy: 0.7335
# Epoch 10/20
# 546/546 [==============================] - 0s 888us/step - loss: 0.6591 - sparse_categorical_accuracy: 0.7520
# Epoch 11/20
# 546/546 [==============================] - 0s 874us/step - loss: 0.6179 - sparse_categorical_accuracy: 0.7694
# Epoch 12/20
# 546/546 [==============================] - 0s 860us/step - loss: 0.5950 - sparse_categorical_accuracy: 0.7766
# Epoch 13/20
# 546/546 [==============================] - 0s 889us/step - loss: 0.5753 - sparse_categorical_accuracy: 0.7846
# Epoch 14/20
# 546/546 [==============================] - 0s 866us/step - loss: 0.5531 - sparse_categorical_accuracy: 0.7991
# Epoch 15/20
# 546/546 [==============================] - 0s 853us/step - loss: 0.5328 - sparse_categorical_accuracy: 0.8121
# Epoch 16/20
# 546/546 [==============================] - 0s 882us/step - loss: 0.5082 - sparse_categorical_accuracy: 0.8266
# Epoch 17/20
# 546/546 [==============================] - 0s 874us/step - loss: 0.4817 - sparse_categorical_accuracy: 0.8405
# Epoch 18/20
# 546/546 [==============================] - 0s 847us/step - loss: 0.4646 - sparse_categorical_accuracy: 0.8496
# Epoch 19/20
# 546/546 [==============================] - 1s 941us/step - loss: 0.4354 - sparse_categorical_accuracy: 0.8593
# Epoch 20/20
# 546/546 [==============================] - 0s 862us/step - loss: 0.4148 - sparse_categorical_accuracy: 0.8731
# 137/137 [==============================] - 0s 1ms/step - loss: 1.0183 - sparse_categorical_accuracy: 0.6872
# Train for 546 steps
# Epoch 1/20
# 546/546 [==============================] - 1s 1ms/step - loss: 1.5307 - sparse_categorical_accuracy: 0.3974
# Epoch 2/20
# 546/546 [==============================] - 0s 881us/step - loss: 1.1487 - sparse_categorical_accuracy: 0.4837
# Epoch 3/20
# 546/546 [==============================] - 0s 889us/step - loss: 1.0794 - sparse_categorical_accuracy: 0.5119
# Epoch 4/20
# 546/546 [==============================] - 0s 874us/step - loss: 1.0372 - sparse_categorical_accuracy: 0.5344
# Epoch 5/20
# 546/546 [==============================] - 0s 884us/step - loss: 1.0160 - sparse_categorical_accuracy: 0.5434
# Epoch 6/20
# 546/546 [==============================] - 0s 880us/step - loss: 1.0001 - sparse_categorical_accuracy: 0.5513
# Epoch 7/20
# 546/546 [==============================] - 0s 895us/step - loss: 0.9797 - sparse_categorical_accuracy: 0.5582
# Epoch 8/20
# 546/546 [==============================] - 0s 893us/step - loss: 0.9686 - sparse_categorical_accuracy: 0.5606
# Epoch 9/20
# 546/546 [==============================] - 0s 911us/step - loss: 0.9564 - sparse_categorical_accuracy: 0.5615
# Epoch 10/20
# 546/546 [==============================] - 0s 861us/step - loss: 0.9490 - sparse_categorical_accuracy: 0.5676
# Epoch 11/20
# 546/546 [==============================] - 0s 861us/step - loss: 0.9279 - sparse_categorical_accuracy: 0.5727
# Epoch 12/20
# 546/546 [==============================] - 0s 869us/step - loss: 0.8901 - sparse_categorical_accuracy: 0.6000
# Epoch 13/20
# 546/546 [==============================] - 0s 892us/step - loss: 0.8605 - sparse_categorical_accuracy: 0.6452
# Epoch 14/20
# 546/546 [==============================] - 0s 886us/step - loss: 0.8194 - sparse_categorical_accuracy: 0.6795
# Epoch 15/20
# 546/546 [==============================] - 0s 892us/step - loss: 0.7694 - sparse_categorical_accuracy: 0.7013
# Epoch 16/20
# 546/546 [==============================] - 0s 897us/step - loss: 0.6966 - sparse_categorical_accuracy: 0.7326
# Epoch 17/20
# 546/546 [==============================] - 0s 886us/step - loss: 0.6367 - sparse_categorical_accuracy: 0.7709
# Epoch 18/20
# 546/546 [==============================] - 0s 892us/step - loss: 0.6007 - sparse_categorical_accuracy: 0.7872
# Epoch 19/20
# 546/546 [==============================] - 0s 885us/step - loss: 0.5853 - sparse_categorical_accuracy: 0.8007
# Epoch 20/20
# 546/546 [==============================] - 0s 887us/step - loss: 0.5679 - sparse_categorical_accuracy: 0.8119
# 137/137 [==============================] - 0s 1ms/step - loss: 1.1266 - sparse_categorical_accuracy: 0.6513
# Train for 546 steps
# Epoch 1/20
# 546/546 [==============================] - 1s 1ms/step - loss: 1.4746 - sparse_categorical_accuracy: 0.4024
# Epoch 2/20
# 546/546 [==============================] - 0s 908us/step - loss: 1.1609 - sparse_categorical_accuracy: 0.4670
# Epoch 3/20
# 546/546 [==============================] - 0s 858us/step - loss: 1.1114 - sparse_categorical_accuracy: 0.4846
# Epoch 4/20
# 546/546 [==============================] - 0s 893us/step - loss: 1.0773 - sparse_categorical_accuracy: 0.5011
# Epoch 5/20
# 546/546 [==============================] - 0s 895us/step - loss: 1.0423 - sparse_categorical_accuracy: 0.5229
# Epoch 6/20
# 546/546 [==============================] - 0s 891us/step - loss: 0.9642 - sparse_categorical_accuracy: 0.5929
# Epoch 7/20
# 546/546 [==============================] - 0s 886us/step - loss: 0.9006 - sparse_categorical_accuracy: 0.6348
# Epoch 8/20
# 546/546 [==============================] - 0s 913us/step - loss: 0.8653 - sparse_categorical_accuracy: 0.6650
# Epoch 9/20
# 546/546 [==============================] - 1s 923us/step - loss: 0.8168 - sparse_categorical_accuracy: 0.6918
# Epoch 10/20
# 546/546 [==============================] - 0s 879us/step - loss: 0.7742 - sparse_categorical_accuracy: 0.7110
# Epoch 11/20
# 546/546 [==============================] - 0s 865us/step - loss: 0.7460 - sparse_categorical_accuracy: 0.7288
# Epoch 12/20
# 546/546 [==============================] - 0s 834us/step - loss: 0.7277 - sparse_categorical_accuracy: 0.7357
# Epoch 13/20
# 546/546 [==============================] - 0s 878us/step - loss: 0.7007 - sparse_categorical_accuracy: 0.7511
# Epoch 14/20
# 546/546 [==============================] - 0s 897us/step - loss: 0.6751 - sparse_categorical_accuracy: 0.7604
# Epoch 15/20
# 546/546 [==============================] - 0s 871us/step - loss: 0.6497 - sparse_categorical_accuracy: 0.7742
# Epoch 16/20
# 546/546 [==============================] - 0s 871us/step - loss: 0.6546 - sparse_categorical_accuracy: 0.7756
# Epoch 17/20
# 546/546 [==============================] - 0s 894us/step - loss: 0.6254 - sparse_categorical_accuracy: 0.7859
# Epoch 18/20
# 546/546 [==============================] - 0s 861us/step - loss: 0.5963 - sparse_categorical_accuracy: 0.8005
# Epoch 19/20
# 546/546 [==============================] - 0s 879us/step - loss: 0.5795 - sparse_categorical_accuracy: 0.8097
# Epoch 20/20
# 546/546 [==============================] - 1s 922us/step - loss: 0.5547 - sparse_categorical_accuracy: 0.8278
# 137/137 [==============================] - 0s 1ms/step - loss: 0.9869 - sparse_categorical_accuracy: 0.6659
# Train for 546 steps
# Epoch 1/20
# 546/546 [==============================] - 1s 1ms/step - loss: 1.5229 - sparse_categorical_accuracy: 0.3522
# Epoch 2/20
# 546/546 [==============================] - 1s 916us/step - loss: 1.1547 - sparse_categorical_accuracy: 0.4987
# Epoch 3/20
# 546/546 [==============================] - 0s 888us/step - loss: 1.0358 - sparse_categorical_accuracy: 0.5890
# Epoch 4/20
# 546/546 [==============================] - 1s 955us/step - loss: 0.9722 - sparse_categorical_accuracy: 0.6176
# Epoch 5/20
# 546/546 [==============================] - 0s 883us/step - loss: 0.9303 - sparse_categorical_accuracy: 0.6429
# Epoch 6/20
# 546/546 [==============================] - 0s 858us/step - loss: 0.9072 - sparse_categorical_accuracy: 0.6551
# Epoch 7/20
# 546/546 [==============================] - 1s 929us/step - loss: 0.8854 - sparse_categorical_accuracy: 0.6661
# Epoch 8/20
# 546/546 [==============================] - 1s 949us/step - loss: 0.8594 - sparse_categorical_accuracy: 0.6802
# Epoch 9/20
# 546/546 [==============================] - 1s 950us/step - loss: 0.8423 - sparse_categorical_accuracy: 0.6916
# Epoch 10/20
# 546/546 [==============================] - 0s 867us/step - loss: 0.8374 - sparse_categorical_accuracy: 0.6883
# Epoch 11/20
# 546/546 [==============================] - 0s 852us/step - loss: 0.8194 - sparse_categorical_accuracy: 0.6963
# Epoch 12/20
# 546/546 [==============================] - 0s 840us/step - loss: 0.8136 - sparse_categorical_accuracy: 0.7024
# Epoch 13/20
# 546/546 [==============================] - 0s 905us/step - loss: 0.8108 - sparse_categorical_accuracy: 0.7077
# Epoch 14/20
# 546/546 [==============================] - 0s 862us/step - loss: 0.7988 - sparse_categorical_accuracy: 0.7152
# Epoch 15/20
# 546/546 [==============================] - 0s 838us/step - loss: 0.7815 - sparse_categorical_accuracy: 0.7196
# Epoch 16/20
# 546/546 [==============================] - 0s 878us/step - loss: 0.7765 - sparse_categorical_accuracy: 0.7242
# Epoch 17/20
# 546/546 [==============================] - 0s 858us/step - loss: 0.7777 - sparse_categorical_accuracy: 0.7223
# Epoch 18/20
# 546/546 [==============================] - 0s 835us/step - loss: 0.7615 - sparse_categorical_accuracy: 0.7341
# Epoch 19/20
# 546/546 [==============================] - 0s 870us/step - loss: 0.7794 - sparse_categorical_accuracy: 0.7278
# Epoch 20/20
# 546/546 [==============================] - 1s 923us/step - loss: 0.7632 - sparse_categorical_accuracy: 0.7366
# 137/137 [==============================] - 0s 1ms/step - loss: 0.9717 - sparse_categorical_accuracy: 0.6623
# Train for 546 steps
# Epoch 1/20
# 546/546 [==============================] - 1s 2ms/step - loss: 1.3778 - sparse_categorical_accuracy: 0.4467
# Epoch 2/20
# 546/546 [==============================] - 0s 880us/step - loss: 1.0885 - sparse_categorical_accuracy: 0.5212
# Epoch 3/20
# 546/546 [==============================] - 0s 889us/step - loss: 1.0228 - sparse_categorical_accuracy: 0.5824
# Epoch 4/20
# 546/546 [==============================] - 0s 891us/step - loss: 0.9493 - sparse_categorical_accuracy: 0.6370
# Epoch 5/20
# 546/546 [==============================] - 0s 898us/step - loss: 0.8965 - sparse_categorical_accuracy: 0.6694
# Epoch 6/20
# 546/546 [==============================] - 0s 890us/step - loss: 0.8556 - sparse_categorical_accuracy: 0.6864
# Epoch 7/20
# 546/546 [==============================] - 0s 904us/step - loss: 0.8335 - sparse_categorical_accuracy: 0.6989
# Epoch 8/20
# 546/546 [==============================] - 0s 889us/step - loss: 0.8028 - sparse_categorical_accuracy: 0.7097
# Epoch 9/20
# 546/546 [==============================] - 0s 895us/step - loss: 0.7812 - sparse_categorical_accuracy: 0.7192
# Epoch 10/20
# 546/546 [==============================] - 0s 905us/step - loss: 0.7562 - sparse_categorical_accuracy: 0.7251
# Epoch 11/20
# 546/546 [==============================] - 0s 864us/step - loss: 0.7332 - sparse_categorical_accuracy: 0.7440
# Epoch 12/20
# 546/546 [==============================] - 0s 854us/step - loss: 0.7197 - sparse_categorical_accuracy: 0.7462
# Epoch 13/20
# 546/546 [==============================] - 0s 874us/step - loss: 0.7183 - sparse_categorical_accuracy: 0.7489
# Epoch 14/20
# 546/546 [==============================] - 0s 881us/step - loss: 0.7262 - sparse_categorical_accuracy: 0.7454
# Epoch 15/20
# 546/546 [==============================] - 0s 864us/step - loss: 0.7021 - sparse_categorical_accuracy: 0.7564
# Epoch 16/20
# 546/546 [==============================] - 0s 869us/step - loss: 0.6756 - sparse_categorical_accuracy: 0.7659
# Epoch 17/20
# 546/546 [==============================] - 0s 866us/step - loss: 0.6631 - sparse_categorical_accuracy: 0.7705
# Epoch 18/20
# 546/546 [==============================] - 0s 880us/step - loss: 0.6672 - sparse_categorical_accuracy: 0.7683
# Epoch 19/20
# 546/546 [==============================] - 0s 903us/step - loss: 0.6479 - sparse_categorical_accuracy: 0.7795
# Epoch 20/20
# 546/546 [==============================] - 1s 954us/step - loss: 0.6547 - sparse_categorical_accuracy: 0.7760
# 137/137 [==============================] - 0s 1ms/step - loss: 0.9216 - sparse_categorical_accuracy: 0.6747
# Train for 546 steps
# Epoch 1/20
# 546/546 [==============================] - 1s 1ms/step - loss: 1.5005 - sparse_categorical_accuracy: 0.3401
# Epoch 2/20
# 546/546 [==============================] - 1s 920us/step - loss: 1.2288 - sparse_categorical_accuracy: 0.4275
# Epoch 3/20
# 546/546 [==============================] - 0s 872us/step - loss: 1.1579 - sparse_categorical_accuracy: 0.4639
# Epoch 4/20
# 546/546 [==============================] - 0s 888us/step - loss: 1.1123 - sparse_categorical_accuracy: 0.4868
# Epoch 5/20
# 546/546 [==============================] - 1s 952us/step - loss: 1.0800 - sparse_categorical_accuracy: 0.5027
# Epoch 6/20
# 546/546 [==============================] - 0s 873us/step - loss: 1.0268 - sparse_categorical_accuracy: 0.5286
# Epoch 7/20
# 546/546 [==============================] - 0s 892us/step - loss: 0.9873 - sparse_categorical_accuracy: 0.5500
# Epoch 8/20
# 546/546 [==============================] - 0s 896us/step - loss: 0.9757 - sparse_categorical_accuracy: 0.5592
# Epoch 9/20
# 546/546 [==============================] - 0s 889us/step - loss: 0.9466 - sparse_categorical_accuracy: 0.5892
# Epoch 10/20
# 546/546 [==============================] - 1s 932us/step - loss: 0.9071 - sparse_categorical_accuracy: 0.6211
# Epoch 11/20
# 546/546 [==============================] - 0s 858us/step - loss: 0.8833 - sparse_categorical_accuracy: 0.6333
# Epoch 12/20
# 546/546 [==============================] - 0s 851us/step - loss: 0.8812 - sparse_categorical_accuracy: 0.6462
# Epoch 13/20
# 546/546 [==============================] - 0s 860us/step - loss: 0.8530 - sparse_categorical_accuracy: 0.6648
# Epoch 14/20
# 546/546 [==============================] - 0s 903us/step - loss: 0.8315 - sparse_categorical_accuracy: 0.6800
# Epoch 15/20
# 546/546 [==============================] - 0s 868us/step - loss: 0.8329 - sparse_categorical_accuracy: 0.6870
# Epoch 16/20
# 546/546 [==============================] - 0s 875us/step - loss: 0.8175 - sparse_categorical_accuracy: 0.6932
# Epoch 17/20
# 546/546 [==============================] - 0s 908us/step - loss: 0.8116 - sparse_categorical_accuracy: 0.6976
# Epoch 18/20
# 546/546 [==============================] - 0s 857us/step - loss: 0.8049 - sparse_categorical_accuracy: 0.7022
# Epoch 19/20
# 546/546 [==============================] - 0s 903us/step - loss: 0.7938 - sparse_categorical_accuracy: 0.7062
# Epoch 20/20
# 546/546 [==============================] - 1s 922us/step - loss: 0.7888 - sparse_categorical_accuracy: 0.7158
# 137/137 [==============================] - 0s 1ms/step - loss: 0.9828 - sparse_categorical_accuracy: 0.6103
# lr =  0.001
# lr =  0.002
# lr =  0.003
# lr =  0.004
# lr =  0.005
# lr =  0.006
# lr =  0.007
# lr =  0.008
# lr =  0.009000000000000001
# lr =  0.010000000000000002
# accuracy =  0.6
# accuracy =  0.64
# accuracy =  0.68
# accuracy =  0.68
# accuracy =  0.69
# accuracy =  0.65
# accuracy =  0.67
# accuracy =  0.66
# accuracy =  0.67
# accuracy =  0.61

# %%
# Plot the "Impact of Learning Rate on Accuracy" with learning_rates on x-axis and accuracies on y_axis
# Plot must have title and axis labels. Incomplete plots will get NO CREDIT!
plt.plot(learning_rates, accuracies)
plt.title('Impact of Learning Rate on Accuracy')
plt.xlabel('Learning Rates')
plt.ylabel('Accuracies')
# Out:
# Text(0, 0.5, 'Accuracies')

# %% [markdown]
# ## Part I - Questions

# %% [markdown]
# ANSWER THE FOLLOWING QUESTIONS HERE:
#
# **Q1 [5 points]** - According to your learning rate fine-tuning plot, what is a good value for learning rate?
# <br> 0.005 was the best according to the plot <br>
# **Q2 [5 points]** - If you change the batch size in `train_batch` and `test_batch`:
#
# (a - 2 points) would it increase or decrease the speed of training? Also, would it increase or decrease the accuracy? YOU MUST DO EXPERIMENTS and report whether training speed and accuracy increase or decrease by changing batch size.
# <br>The smaller the batch sizes, the faster the training and also generalizes the data better compared to larger sizes. <br>
# <br>(b - 3 points) Explain why those observations on training speed and accuracy happen. <br>
# The smaller the data set means there is less data to train, thus the time to train decreases. When the data set increases in size, the more error could happen, and it is harder to generalize the more data you have. So accuracy is also going to decrease.
#
# **Q3 [5 points]** - Name five learning rate scheduling policies known as **learning schedules** (you may consult with the textbook), and explain each briefly in no more than two sentences.
# <br> Performance scheduling: Measure the validation error every N steps and reduce the learning rate by a factor of lamba when the error stops dropping.<br>
# <br> Piecewise constant scheduling: Uss a constant learning rate for a number of epons then a smaller learning rate for another number of epochs<br>
# <br> Time-based: learning schedules alter the learning rate dependoning on the learning rate of the previous time iteration<br>
# <br> Step-based: learning schedule changes the learning rate according to some pre defined steps <br>
# <br> Exponential: learning schedule are similar to step-based but insread of steps a decreasing exponetial is used<br>

# %% [markdown]
# ## Part II - Regression Using NNs

# %% [markdown]
# In Part II, you're going to perform regression using NNs.

# %% [markdown]
# You're going to predict `NA_Sales` based on other sales in the world. It is possible to frame the regression problem with other values as target, but this is how you're going to do regression practice for Part II. Notice that you should already drop `Global_Sales` from your game_data.

# %% [markdown]
# ## <font color="red"> Required Coding

# %%
# Get feature vector X_reg (all columns but "NA_Sales") and target label y_reg as "NA_Sales"
X_reg = game_data.loc[:,game_data.columns != 'NA_Sales']
y_reg = game_data['NA_Sales']

# %%
# Print X_reg shape and head
print(X_reg.shape)
X_reg.head()
# Out:
# (6825, 13)
#   Platform  Year_of_Release     Genre Publisher  EU_Sales  JP_Sales  \
# 0      Wii           2006.0    Sports  Nintendo     28.96      3.77
# 2      Wii           2008.0    Racing  Nintendo     12.76      3.79
# 3      Wii           2009.0    Sports  Nintendo     10.93      3.28
# 6       DS           2006.0  Platform  Nintendo      9.14      6.50
# 7      Wii           2006.0      Misc  Nintendo      9.18      2.93
#
#    Other_Sales  Critic_Score  Critic_Count User_Score  User_Count Developer  \
# 0         8.45          76.0          51.0          8       322.0  Nintendo
# 2         3.29          82.0          73.0        8.3       709.0  Nintendo
# 3         2.95          80.0          73.0          8       192.0  Nintendo
# 6         2.88          89.0          65.0        8.5       431.0  Nintendo
# 7         2.84          58.0          41.0        6.6       129.0  Nintendo
#
#   Rating
# 0      E
# 2      E
# 3      E
# 6      E
# 7      E

# %%
# Using pandas.get_dummies() create dummy variables for categorical features
X_reg = pd.get_dummies(X_reg)
print(X_reg.shape)
X_reg.head()
# Out:
# (6825, 1683)
#    Year_of_Release  EU_Sales  JP_Sales  Other_Sales  Critic_Score  \
# 0           2006.0     28.96      3.77         8.45          76.0
# 2           2008.0     12.76      3.79         3.29          82.0
# 3           2009.0     10.93      3.28         2.95          80.0
# 6           2006.0      9.14      6.50         2.88          89.0
# 7           2006.0      9.18      2.93         2.84          58.0
#
#    Critic_Count  User_Count  Platform_3DS  Platform_DC  Platform_DS  ...  \
# 0          51.0       322.0             0            0            0  ...
# 2          73.0       709.0             0            0            0  ...
# 3          73.0       192.0             0            0            0  ...
# 6          65.0       431.0             0            0            1  ...
# 7          41.0       129.0             0            0            0  ...
#
#    Developer_odenis studio  Developer_syn Sophia  Developer_zSlide  Rating_AO  \
# 0                        0                     0                 0          0
# 2                        0                     0                 0          0
# 3                        0                     0                 0          0
# 6                        0                     0                 0          0
# 7                        0                     0                 0          0
#
#    Rating_E  Rating_E10+  Rating_K-A  Rating_M  Rating_RP  Rating_T
# 0         1            0           0         0          0         0
# 2         1            0           0         0          0         0
# 3         1            0           0         0          0         0
# 6         1            0           0         0          0         0
# 7         1            0           0         0          0         0
#
# [5 rows x 1683 columns]

# %%
# Normalize X_reg using mean() and std()  NOTE: The output is provided for your reference.
mean = np.mean(X_reg)
std = np.std(X_reg)
X_reg -= mean
X_reg /= std
print(X_reg.shape)
X_reg.head()
# Out:
# (6825, 1683)
#    Year_of_Release   EU_Sales   JP_Sales  Other_Sales  Critic_Score  \
# 0        -0.341201  41.793631  12.887711    31.007176      0.413044
# 2         0.133752  18.222438  12.957265    11.885525      0.845709
# 3         0.371229  15.559767  11.183651    10.625572      0.701487
# 6        -0.341201  12.955296  22.381762    10.366169      1.350484
# 7        -0.341201  13.013496   9.966465    10.217939     -0.884950
#
#    Critic_Count  User_Count  Platform_3DS  Platform_DC  Platform_DS  ...  \
# 0      1.148059    0.250734     -0.152441    -0.045338    -0.270082  ...
# 2      2.292536    0.909586     -0.152441    -0.045338    -0.270082  ...
# 3      2.292536    0.029415     -0.152441    -0.045338    -0.270082  ...
# 6      1.876363    0.436302     -0.152441    -0.045338     3.702574  ...
# 7      0.627843   -0.077840     -0.152441    -0.045338    -0.270082  ...
#
#    Developer_odenis studio  Developer_syn Sophia  Developer_zSlide  Rating_AO  \
# 0                -0.012105             -0.017121         -0.012105  -0.012105
# 2                -0.012105             -0.017121         -0.012105  -0.012105
# 3                -0.012105             -0.017121         -0.012105  -0.012105
# 6                -0.012105             -0.017121         -0.012105  -0.012105
# 7                -0.012105             -0.017121         -0.012105  -0.012105
#
#    Rating_E  Rating_E10+  Rating_K-A  Rating_M  Rating_RP  Rating_T
# 0  1.509337    -0.397191   -0.012105 -0.515523  -0.012105 -0.731025
# 2  1.509337    -0.397191   -0.012105 -0.515523  -0.012105 -0.731025
# 3  1.509337    -0.397191   -0.012105 -0.515523  -0.012105 -0.731025
# 6  1.509337    -0.397191   -0.012105 -0.515523  -0.012105 -0.731025
# 7  1.509337    -0.397191   -0.012105 -0.515523  -0.012105 -0.731025
#
# [5 rows x 1683 columns]

# %%
# Split the data to train and test with ratio of 80/20 for train/test respectively
X_reg_train, X_reg_test, y_reg_train, y_reg_test = train_test_split(X_reg,y_reg,train_size=.80,test_size=.2)

print(X_reg_train.shape)
print(y_reg_train.shape)
print(X_reg_test.shape)
print(y_reg_test.shape)
# Out:
# (5460, 1683)
# (5460,)
# (1365, 1683)
# (1365,)

# %%
# Batch the data
train_tensor_reg = tf.data.Dataset.from_tensor_slices((X_reg_train.values, y_reg_train.values))
test_tensor_reg = tf.data.Dataset.from_tensor_slices((X_reg_test.values, y_reg_test.values))
train_batch_reg = train_tensor_reg.shuffle(len(X_reg_train)).batch(10)
test_batch_reg = test_tensor_reg.shuffle(len(X_reg_test)).batch(10)

# %%
train_tensor_reg.element_spec
# Out:
# (TensorSpec(shape=(1683,), dtype=tf.float64, name=None),
#  TensorSpec(shape=(), dtype=tf.float64, name=None))

# %% [markdown]
# ### Building NN for Regression

# %%
# Build a sequential NN with appropriate layers for regression
# Use ReLU for all hidden layers

# Hint1: input_dim of the first layer should match with the number of features in X_train_reg
# Hint2: Notice that the activation function and number of neurons in the output layer are determined
# by the type of ML task i.e. Regression

nn_reg = tf.keras.Sequential([
    # Add layers accordingly
    layers.Dense(1683,input_dim=X_reg_train.shape[1], activation="relu", name="layer1"),
    layers.Dense(2, activation="relu"),
    layers.Dense(1, activation="relu")
    ])

# %%
nn_reg.summary()
# Out:
# Model: "sequential_64"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# layer1 (Dense)               (None, 1683)              2834172
# _________________________________________________________________
# dense_18 (Dense)             (None, 2)                 3368
# _________________________________________________________________
# dense_19 (Dense)             (None, 1)                 3
# =================================================================
# Total params: 2,837,543
# Trainable params: 2,837,543
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile nn_reg with appropriate loss and metric

# Hint1: You need to choose the loss and metric for regression
# Hint2: For this regression task, loss and metrics might be the same
reg_opt = keras.optimizers.RMSprop(learning_rate=0.001)
nn_reg.compile(loss='mse',optimizer=reg_opt,metrics=['mse'])

# %%
# Fit the network on train_batch_reg with 20 epochs
nn_reg_history = nn_reg.fit(train_batch_reg,epochs=20)
# Out:
# Train for 546 steps
# Epoch 1/20
# 546/546 [==============================] - 9s 16ms/step - loss: 0.4352 - mse: 0.4352
# Epoch 2/20
# 546/546 [==============================] - 10s 17ms/step - loss: 0.2973 - mse: 0.2973
# Epoch 3/20
# 546/546 [==============================] - 10s 18ms/step - loss: 0.2265 - mse: 0.2265
# Epoch 4/20
# 546/546 [==============================] - 9s 17ms/step - loss: 0.1778 - mse: 0.1778
# Epoch 5/20
# 546/546 [==============================] - 9s 16ms/step - loss: 0.1506 - mse: 0.1506
# Epoch 6/20
# 546/546 [==============================] - 10s 19ms/step - loss: 0.1601 - mse: 0.1601
# Epoch 7/20
# 546/546 [==============================] - 9s 16ms/step - loss: 0.1227 - mse: 0.1227
# Epoch 8/20
# 546/546 [==============================] - 9s 16ms/step - loss: 0.1267 - mse: 0.1267: 1s - loss: 0.12
# Epoch 9/20
# 546/546 [==============================] - 9s 16ms/step - loss: 0.1011 - mse: 0.1011
# Epoch 10/20
# 546/546 [==============================] - 9s 16ms/step - loss: 0.0990 - mse: 0.0990
# Epoch 11/20
# 546/546 [==============================] - 10s 18ms/step - loss: 0.0871 - mse: 0.0871
# Epoch 12/20
# 546/546 [==============================] - 10s 18ms/step - loss: 0.0836 - mse: 0.0836 1s - lo
# Epoch 13/20
# 546/546 [==============================] - 9s 16ms/step - loss: 0.0813 - mse: 0.0813
# Epoch 14/20
# 546/546 [==============================] - 9s 16ms/step - loss: 0.0864 - mse: 0.0864
# Epoch 15/20
# 546/546 [==============================] - 9s 17ms/step - loss: 0.0735 - mse: 0.0735
# Epoch 16/20
# 546/546 [==============================] - 8s 15ms/step - loss: 0.0837 - mse: 0.0837
# Epoch 17/20
# 546/546 [==============================] - 9s 17ms/step - loss: 0.0625 - mse: 0.0625
# Epoch 18/20
# 546/546 [==============================] - 9s 17ms/step - loss: 0.0588 - mse: 0.0588
# Epoch 19/20
# 546/546 [==============================] - 9s 16ms/step - loss: 0.0551 - mse: 0.0551
# Epoch 20/20
# 546/546 [==============================] - 10s 18ms/step - loss: 0.0527 - mse: 0.0527

# %%
pd.DataFrame(nn_reg_history.history).plot(figsize=(10, 5))
plt.grid(True)

# Set the xticks - label locations
plt.xticks(np.arange(0, 20, step=2))  

# set the y-axis range to [0-1]
plt.gca().set_ylim(0, 1)
# Out:
# (0, 1)

# %% [markdown]
# > <font color='red'>**Maximum Acceptable Loss Requirement**</font>: Your loss on `test_batch_reg` should not exceed **0.15**. Otherwise, your notebook will get NO CREDIT for this part, so you must fine-tune your `nn_reg` accordingly.

# %%
# Evaluate the model on test_batch_reg
loss, metric = nn_reg.evaluate(test_batch_reg)
# Out:
# 137/137 [==============================] - 0s 2ms/step - loss: 0.1368 - mse: 0.1373

# %%
# Maximum acceptable loss: 0.15
round(loss, 2)
# Out:
# 0.14

# %% [markdown]
# > Next, you're going to build another NN and use callback and early stopping to determine the optimal number of epochs.

# %%
# Build a sequential NN with appropriate layers for regression
# Use ReLU for all hidden layers

# Hint1: input_dim of the first layer should match with the number of features in X_train_reg
# Hint2: Notice that the activation function and number of neurons in the output layer are determined
# by the type of ML task i.e. Regression

nn_reg2 = tf.keras.Sequential([
    # Add layers accordingly
    layers.Dense(1683,input_dim=X_reg_train.shape[1], activation="relu", name="layer1"),
    layers.Dense(2, activation="relu"),
    layers.Dense(1, activation="relu")
    ])

# %%
# Create an optimizer of your choice with a learning rate of 0.001
optimizer = keras.optimizers.RMSprop(learning_rate=0.001)

# %% [markdown]
# > Next, you're going to create `callbacks` and `EarlyStopping`.
#
# > **Note:** The `patience` parameter is the number of epochs to monitor for improvement. You may want to look up textbook examples to learn how to do this, but notice that there is no validation data here.

# %%
# Create a tf.keras.callbacks with EarlyStopping method and monitor='loss' and patience=10 
early_stop = tf.keras.callbacks.EarlyStopping(monitor='loss', patience=10)

# %%
# Compile nn_reg2 with appropriate loss, optimizer=optimizer and TWO metrics for regression
# Hint: The two metrics must be both for regression, and one of them may be the same as loss
nn_reg2.compile(loss='mse',optimizer=optimizer,metrics=['mse','mae'])

# %% [markdown]
# > Now run the training, sit back and let tf/keras determine the optimal number of epochs!

# %%
EPOCHS = 1000
# Fit nn_reg2 on train_batch_reg, epochs=EPOCHS, callbacks=[early_stop]
nn_reg2_history = nn_reg2.fit(train_batch_reg, epochs=EPOCHS, callbacks=[early_stop])
# Out:
# Train for 546 steps
# Epoch 1/1000
# 546/546 [==============================] - 9s 16ms/step - loss: 1.1662 - mse: 1.1662 - mae: 0.3988
# Epoch 2/1000
# 546/546 [==============================] - 10s 17ms/step - loss: 1.1662 - mse: 1.1662 - mae: 0.3988
# Epoch 3/1000
# 546/546 [==============================] - 8s 15ms/step - loss: 1.1662 - mse: 1.1662 - mae: 0.3988
# Epoch 4/1000
# 546/546 [==============================] - 8s 15ms/step - loss: 1.1662 - mse: 1.1662 - mae: 0.3988
# Epoch 5/1000
# 546/546 [==============================] - 9s 16ms/step - loss: 1.1662 - mse: 1.1662 - mae: 0.3988
# Epoch 6/1000
# 546/546 [==============================] - 8s 14ms/step - loss: 1.1662 - mse: 1.1662 - mae: 0.3988
# Epoch 7/1000
# 546/546 [==============================] - 8s 14ms/step - loss: 1.1662 - mse: 1.1662 - mae: 0.3988
# Epoch 8/1000
# 546/546 [==============================] - 8s 14ms/step - loss: 1.1662 - mse: 1.1662 - mae: 0.3988
# Epoch 9/1000
# 546/546 [==============================] - 8s 14ms/step - loss: 1.1662 - mse: 1.1662 - mae: 0.3988
# Epoch 10/1000
# 546/546 [==============================] - 8s 14ms/step - loss: 1.1662 - mse: 1.1662 - mae: 0.3988
# Epoch 11/1000
# 546/546 [==============================] - 8s 14ms/step - loss: 1.1662 - mse: 1.1662 - mae: 0.3988
# Epoch 12/1000
# 546/546 [==============================] - 8s 14ms/step - loss: 1.1662 - mse: 1.1662 - mae: 0.3988
# Epoch 13/1000
# 546/546 [==============================] - 8s 14ms/step - loss: 1.1662 - mse: 1.1662 - mae: 0.3988
# Epoch 14/1000
# 546/546 [==============================] - 8s 14ms/step - loss: 1.1662 - mse: 1.1662 - mae: 0.3988
# Epoch 15/1000
# 546/546 [==============================] - 8s 14ms/step - loss: 1.1662 - mse: 1.1662 - mae: 0.3988
# Epoch 16/1000
# 546/546 [==============================] - 8s 15ms/step - loss: 1.1662 - mse: 1.1662 - mae: 0.3988

# %%
pd.DataFrame(nn_reg2_history.history).plot(figsize=(10, 5))
plt.grid(True)

# set the y-axis range to [0-1]
plt.gca().set_ylim(0, 6)
# Out:
# (0, 6)

# %% [markdown]
# ## Part II - Questions

# %% [markdown]
# ANSWER THE FOLLOWING QUESTIONS HERE:
#
# **Q1 [5 points]** <br>
# (a - 3 points) - Using eraly stopping and callbacks, how may epochs did the training run for `nn_reg2`? Find the attribute in history object that logs number of epochs. Write the code to get number of epochs in the following cell.
#
# (b - 2 points) - How did the training stop? Your answer should exactly mention the criteria for when the training stops. EXPLAIN CLEARLY AND COMPLETELY IN NO MORE THAN TWO SENTENCES!
# <br> The training stop as the loss was not changing, it reached a local minimum thus early stopping occoured <br>

# %%
# Get number of epochs from history object (Hint: it would return a list)
print(len(nn_reg2_history.history['loss']))
# Out:
# 16

# %% [markdown]
# **Q2 [5 points]** - On the history plot of `nn_reg2`, you have three colors/curves, but only two of them are displayed. Explain why?
# At least for my case, loss and mse is the same thing, so that may be one reason. Another reason that loss it not being graphed is that it may not changing so it.

# %% [markdown]
# ## Grading
#
# Assignment-4 has a maximum of 100 points. Make sure that you get the correct outputs for all cells that you implement and give complete answers to all questions. Also, your notebook should be written with no grammatical and spelling errors and should be easy-to-read.
#
# The breakdown of the 100 points is as follows:
#
# - Part I Classification on Rating: [total 70 points]
#     - Implementation of nn_clf: 40 points - **Minimum Required Accuracy**: 0.70 otherwise ZERO CREDIT!
#     - Learning rate fine-tuning plot: 15 points
#     - Questions: 15 points (5 points each)
#
#
# - Part II Regression on NA_Sales: [total 30 points]
#     - Implementation of nn_reg: 10 points - **Maximum Acceptable Loss**: 0.15 otherwise ZERO CREDIT!
#     - Early stopping of nn_reg_2: 10 points
#     - Questions: 10 points (5 points each)
#
#
# <b>Note: </b>Follow the instructions of each section carefully. Up to 10 points may be deducted if your submitted notebook is not easy to read and follow or if it has grammatical, spelling or formatting issues.

# %% [markdown]
# Name your notebook ```Lastname-A4.ipynb```. Submit the completed notebook using the ```Assignment-4``` link on Blackboard.
#
# Grading will be based on
#
#   * correct implementation and results, correct answer to the questions, and
#   * readability of the notebook.
#
# <font color=red><b>Due Date: Monday November 23rd, 11:59PM.</b></font>
